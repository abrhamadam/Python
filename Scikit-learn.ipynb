# %% [markdown]
# # 1/ Installation

# %%
# !pip install scikit-learn
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Hp\\AppData\\Local\\Temp\\pip-uninstall-ydkxaeex\\numpy\\core\\_multiarray_tests.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0

# %% [markdown]
# # 2/ Importing
# import necessary scripts of python scripter

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # 3/  loading the famous iris dataset

# %%
iris = datasets.load_iris()
X = iris.data  # Features
y = iris.target  # Labels

# %% [markdown]
# # 4/ Data preprocessing

# %%
# Example: Scaling features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #  5/ splitting the dataset into train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # 6/ choose model

# %%
# Example: Logistic Regression
model = LogisticRegression()

# %% [markdown]
# #  7/ train the model

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #  8/ make predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #  9/ Evaluate the model

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# #  10/ visualize the project

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 #Create a DataFrame for easy plotting with seaborn
iris_df = pd.DataFrame(data=np.c_[X, y], columns=iris.feature_names + ['target'])

# Pairplot to visualize relationships between features
sns.pairplot(iris_df, hue='target', markers=['o', 's', 'D'], palette='husl')
plt.show()

# Boxplot to visualize feature distributions
plt.figure(figsize=(12, 6))
sns.boxplot(x='target', y='sepal length (cm)', data=iris_df)
plt.title('Sepal Length Distribution by Iris Species')
plt.show()
